# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18_0800_NIC_FINAL_STATE_RAJASTHAN-2011.csv",encoding='latin1')
df2 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18_1200_NIC_FINAL_STATE_ARUNACHAL_PRADESH-2011.csv",encoding='latin1')
df3 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18_1400_NIC_FINAL_STATE_MANIPUR-2011.csv",encoding='latin1')
df4 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18_1500_NIC_FINAL_STATE_MIZORAM-2011.csv",encoding='latin1')
df5 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18_1900_NIC_FINAL_STATE_WEST_BENGAL-2011.csv",encoding='latin1')
df6 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18sc_0700_NIC_FINAL_STATE_NCT_OF_DELHI-2011.csv",encoding='latin1')
df7 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18sc_1600_NIC_FINAL_STATE_TRIPURA-2011.csv",encoding='latin1')
df8 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18sc_2000_NIC_FINAL_STATE_JHARKHAND-2011.csv",encoding='latin1')
df9 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18sc_2400_NIC_FINAL_STATE_GUJARAT-2011.csv",encoding='latin1')
df10 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18sc_2700_NIC_FINAL_STATE_MAHARASHTRA-2011.csv",encoding='latin1')
df11= pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18sc_2900_NIC_FINAL_STATE_KARNATAKA-2011.csv",encoding='latin1')
df12= pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18sc_3000_NIC_FINAL_STATE_GOA-2011.csv",encoding='latin1')
df13= pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18sc_3200_NIC_FINAL_STATE_KERALA-2011.csv",encoding='latin1')
df14 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18sc_3300_NIC_FINAL_STATE_TAMIL_NADU-2011.csv",encoding='latin1')
df15= pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18sc_3400_NIC_FINAL_STATE_PUDUCHERRY-2011.csv",encoding='latin1')
df16= pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18st_0200_NIC_FINAL_STATE_HIMACHAL_PRADESH-2011.csv",encoding='latin1')
df17 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18st_0500_NIC_FINAL_STATE_UTTARAKHAND-2011.csv",encoding='latin1')
df18 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18st_0900_NIC_FINAL_STATE_UTTAR_PRADESH-2011.csv",encoding='latin1')
df19 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18st_1000_NIC_FINAL_STATE_BIHAR-2011.csv",encoding='latin1')
df20 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18st_1100_NIC_FINAL_STATE_SIKKIM-2011.csv",encoding='latin1')
df21 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18st_1300_NIC_FINAL_STATE_NAGALAND-2011.csv",encoding='latin1')
df22 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18st_1800_NIC_FINAL_STATE_ASSAM-2011.csv",encoding='latin1')
df23 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18st_2100_NIC_FINAL_STATE_ODISHA-2011.csv",encoding='latin1')

# %%
df = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23])
df.head()
# Out:
#   State Code District Code       India/States Division Group  Class  \
# 0        `08          `000  STATE - RAJASTHAN      `00  `000  `0000
# 1        `08          `000  STATE - RAJASTHAN      `01  `000  `0000
# 2        `08          `000  STATE - RAJASTHAN      `01  `011  `0000
# 3        `08          `000  STATE - RAJASTHAN      `01  `011  `0111
# 4        `08          `000  STATE - RAJASTHAN      `01  `011  `0112
#
#                                             NIC Name  \
# 0                                              Total
# 1  Crop and animal production, hunting and relate...
# 2                     Growing of non-perennial crops
# 3  Growing of cereals (except rice), leguminous c...
# 4                                    Growing of rice
#
#    Main Workers - Total -  Persons  Main Workers - Total - Males  \
# 0                          9017944                       7594737
# 1                           450766                        201572
# ...

# %%
df.shape
# Out:
# (195145, 25)

# %%
df.to_csv("All_Combine.csv",index=False)

# %%
#  removing unnecessary characters (such as commas, semicolons, and backticks) and converting the cleaned values to integers.
df['State Code'] = df['State Code'].astype(str).str.replace('`','').astype(int)
df['District Code'] = df['District Code'].astype(str).str.replace('`','').astype(int)
df['Division'] = df['Division'].astype(str).str.replace('`','').astype(int)
df['Group'] = df['Group'].astype(str).str.replace('`','').astype(int)
df['Class'] = df['Class'].astype(str).str.replace('`','').astype(int)

# %%
df.columns
# Out:
# Index(['State Code', 'District Code', 'India/States', 'Division', 'Group',
#        'Class', 'NIC Name', 'Main Workers - Total -  Persons',
#        'Main Workers - Total - Males', 'Main Workers - Total - Females',
#        'Main Workers - Rural -  Persons', 'Main Workers - Rural - Males',
#        'Main Workers - Rural - Females', 'Main Workers - Urban -  Persons',
#        'Main Workers - Urban - Males', 'Main Workers - Urban - Females',
#        'Marginal Workers - Total -  Persons',
#        'Marginal Workers - Total - Males',
#        'Marginal Workers - Total - Females',
#        'Marginal Workers - Rural -  Persons',
#        'Marginal Workers - Rural - Males',
#        'Marginal Workers - Rural - Females',
#        'Marginal Workers - Urban -  Persons',
#        'Marginal Workers - Urban - Males',
#        'Marginal Workers - Urban - Females'],
#       dtype='object')

# %%
# removing special characters from the column names.

def remove_special_character(column_name):
    return ''.join(e for e in column_name if e.isalnum() or e in ('_','.'))

df.columns = [remove_special_character(col) for col in df.columns]

# %%
df.columns
# Out:
# Index(['StateCode', 'DistrictCode', 'IndiaStates', 'Division', 'Group',
#        'Class', 'NICName', 'MainWorkersTotalPersons', 'MainWorkersTotalMales',
#        'MainWorkersTotalFemales', 'MainWorkersRuralPersons',
#        'MainWorkersRuralMales', 'MainWorkersRuralFemales',
#        'MainWorkersUrbanPersons', 'MainWorkersUrbanMales',
#        'MainWorkersUrbanFemales', 'MarginalWorkersTotalPersons',
#        'MarginalWorkersTotalMales', 'MarginalWorkersTotalFemales',
#        'MarginalWorkersRuralPersons', 'MarginalWorkersRuralMales',
#        'MarginalWorkersRuralFemales', 'MarginalWorkersUrbanPersons',
#        'MarginalWorkersUrbanMales', 'MarginalWorkersUrbanFemales'],
#       dtype='object')

# %%
df.head()
# Out:
#    StateCode  DistrictCode        IndiaStates  Division  Group  Class  \
# 0          8             0  STATE - RAJASTHAN         0      0      0
# 1          8             0  STATE - RAJASTHAN         1      0      0
# 2          8             0  STATE - RAJASTHAN         1     11      0
# 3          8             0  STATE - RAJASTHAN         1     11    111
# 4          8             0  STATE - RAJASTHAN         1     11    112
#
#                                              NICName  MainWorkersTotalPersons  \
# 0                                              Total                  9017944
# 1  Crop and animal production, hunting and relate...                   450766
# 2                     Growing of non-perennial crops                    12876
# 3  Growing of cereals (except rice), leguminous c...                    12061
# 4                                    Growing of rice                       79
#
#    MainWorkersTotalMales  MainWorkersTotalFemales  ...  \
# ...

# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
# Select Non-Numeric Columns: 
non_numeric_columns = df.select_dtypes(exclude=[float, int]).columns

# Drop Non-Numeric Columns:
numeric_df = df.drop(columns=non_numeric_columns)

# Calculate Correlation: 
correlation_matrix = numeric_df.corr()
correlation_matrix
# Out:
#                              StateCode  DistrictCode  Division     Group  \
# StateCode                     1.000000      0.851207 -0.010642 -0.001695
# DistrictCode                  0.851207      1.000000 -0.005517 -0.005349
# Division                     -0.010642     -0.005517  1.000000  0.744991
# Group                        -0.001695     -0.005349  0.744991  1.000000
# Class                         0.003277     -0.004001  0.438274  0.593097
# MainWorkersTotalPersons      -0.003645     -0.028298 -0.010332 -0.014413
# MainWorkersTotalMales        -0.004775     -0.027999 -0.010797 -0.014439
# MainWorkersTotalFemales       0.001599     -0.027503 -0.007516 -0.013226
# MainWorkersRuralPersons      -0.004710     -0.028544 -0.013753 -0.016427
# MainWorkersRuralMales        -0.005690     -0.028156 -0.013073 -0.015752
# MainWorkersRuralFemales      -0.000498     -0.027300 -0.015046 -0.017440
# MainWorkersUrbanPersons      -0.002714     -0.027413 -0.007376 -0.012471
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def correlation_matrix():
    numberic_df = df.select_dtypes(include= ['float64','int64'])

    plt.figure(figsize=(12,10))
    sns.heatmap(numberic_df.corr(),annot=True,cmap= 'coolwarm', fmt='.2f')
    plt.title('Correlation_Matrix')
    plt.show()

correlation_matrix()

# %%
df.shape
# Out:
# (195145, 25)

# %%
df.head()
# Out:
#    StateCode  DistrictCode        IndiaStates  Division  Group  Class  \
# 0          8             0  STATE - RAJASTHAN         0      0      0
# 1          8             0  STATE - RAJASTHAN         1      0      0
# 2          8             0  STATE - RAJASTHAN         1     11      0
# 3          8             0  STATE - RAJASTHAN         1     11    111
# 4          8             0  STATE - RAJASTHAN         1     11    112
#
#                                              NICName  MainWorkersTotalPersons  \
# 0                                              Total                  9017944
# 1  Crop and animal production, hunting and relate...                   450766
# 2                     Growing of non-perennial crops                    12876
# 3  Growing of cereals (except rice), leguminous c...                    12061
# 4                                    Growing of rice                       79
#
#    MainWorkersTotalMales  MainWorkersTotalFemales  ...  \
# ...

# %%
# finding null values
df.isna().sum()
# Out:
# StateCode                      0
# DistrictCode                   0
# IndiaStates                    0
# Division                       0
# Group                          0
# Class                          0
# NICName                        0
# MainWorkersTotalPersons        0
# MainWorkersTotalMales          0
# MainWorkersTotalFemales        0
# MainWorkersRuralPersons        0
# MainWorkersRuralMales          0
# MainWorkersRuralFemales        0
# MainWorkersUrbanPersons        0
# MainWorkersUrbanMales          0
# MainWorkersUrbanFemales        0
# MarginalWorkersTotalPersons    0
# MarginalWorkersTotalMales      0
# MarginalWorkersTotalFemales    0
# MarginalWorkersRuralPersons    0
# MarginalWorkersRuralMales      0
# MarginalWorkersRuralFemales    0
# MarginalWorkersUrbanPersons    0
# MarginalWorkersUrbanMales      0
# MarginalWorkersUrbanFemales    0
# dtype: int64

# %%
df.describe()
# Out:
#            StateCode   DistrictCode       Division          Group  \
# count  195145.000000  195145.000000  195145.000000  195145.000000
# mean       19.178278     332.223377      46.590351     389.422404
# std         9.057612     196.176206      28.800311     313.186034
# min         2.000000       0.000000       0.000000       0.000000
# 25%        10.000000     153.000000      23.000000     103.000000
# 50%        19.000000     332.000000      46.000000     370.000000
# 75%        27.000000     516.000000      70.000000     631.000000
# max        34.000000     637.000000      99.000000     992.000000
#
#                Class  MainWorkersTotalPersons  MainWorkersTotalMales  \
# count  195145.000000             1.951450e+05           1.951450e+05
# mean     2293.804709             1.492138e+03           1.193171e+03
# std      3059.131669             4.568169e+04           3.773917e+04
# min         0.000000             0.000000e+00           0.000000e+00
# ...

# %%
# to get an overview of the data's distribution and central tendency.
df.describe().T
# Out:
#                                 count         mean           std  min    25%  \
# StateCode                    195145.0    19.178278      9.057612  2.0   10.0
# DistrictCode                 195145.0   332.223377    196.176206  0.0  153.0
# Division                     195145.0    46.590351     28.800311  0.0   23.0
# Group                        195145.0   389.422404    313.186034  0.0  103.0
# Class                        195145.0  2293.804709   3059.131669  0.0    0.0
# MainWorkersTotalPersons      195145.0  1492.137518  45681.690979  0.0    6.0
# MainWorkersTotalMales        195145.0  1193.171150  37739.170774  0.0    6.0
# MainWorkersTotalFemales      195145.0   298.966369   8582.018644  0.0    0.0
# MainWorkersRuralPersons      195145.0   660.618719  20444.364940  0.0    2.0
# MainWorkersRuralMales        195145.0   517.035312  16542.946109  0.0    1.0
# MainWorkersRuralFemales      195145.0   143.583407   4314.446369  0.0    0.0
# ...

# %%
# This method calculates the number of unique values for each column.
df.nunique()
# Out:
# StateCode                        23
# DistrictCode                    472
# IndiaStates                     491
# Division                         89
# Group                           241
# Class                           423
# NICName                         587
# MainWorkersTotalPersons        8679
# MainWorkersTotalMales          7811
# MainWorkersTotalFemales        3970
# MainWorkersRuralPersons        5767
# MainWorkersRuralMales          5218
# MainWorkersRuralFemales        2694
# MainWorkersUrbanPersons        6561
# MainWorkersUrbanMales          5934
# MainWorkersUrbanFemales        2929
# MarginalWorkersTotalPersons    4208
# MarginalWorkersTotalMales      3181
# MarginalWorkersTotalFemales    2850
# MarginalWorkersRuralPersons    3406
# MarginalWorkersRuralMales      2535
# MarginalWorkersRuralFemales    2379
# MarginalWorkersUrbanPersons    2421
# MarginalWorkersUrbanMales      1951
# MarginalWorkersUrbanFemales    1557
# dtype: int64

# %%
sns.histplot(x = 'IndiaStates', data=df)
plt.show()

# %% [markdown]
#  observation:
#
#  The histogram shows the distribution of states in the 'IndiaStates' column. Each bar represents a state, and the height of the bar indicates the frequency of that state in the dataset. From the histogram, we can observe which states occur more frequently and which are less common in the dataset.

# %%
#  creating a box plot using Seaborn's 
x_var = "MarginalWorkersTotalPersons"
y_var = "MainWorkersTotalPersons"
sns.boxplot(x= x_var, y=y_var, data=df)
plt.show()

# %%
# creating scatterplot using seaborn
y_var = "MainWorkersTotalPersons".strip()
sns.scatterplot(x = 'StateCode', y=y_var, data=df)
plt.xlabel('StateCode')
plt.ylabel('NumberofMainWorkers')
plt.title('StateCode')
plt.show()

# %%
# creating boxplot using sns
sns.boxenplot( x = 'NICName', y = 'MarginalWorkersTotalPersons',data=df)
plt.show()
# Out:
# c:\Users\viren\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 146 (\x92) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# DATA CLEANING PROCESS

# %%
#  identify duplicate rows in a DataFrame
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12042    False
# 12043    False
# 12044    False
# 12045    False
# 12046    False
# Length: 195145, dtype: bool

# %%
df.dtypes
# Out:
# StateCode                       int32
# DistrictCode                    int32
# IndiaStates                    object
# Division                        int32
# Group                           int32
# Class                           int32
# NICName                        object
# MainWorkersTotalPersons         int64
# MainWorkersTotalMales           int64
# MainWorkersTotalFemales         int64
# MainWorkersRuralPersons         int64
# MainWorkersRuralMales           int64
# MainWorkersRuralFemales         int64
# MainWorkersUrbanPersons         int64
# MainWorkersUrbanMales           int64
# MainWorkersUrbanFemales         int64
# MarginalWorkersTotalPersons     int64
# MarginalWorkersTotalMales       int64
# MarginalWorkersTotalFemales     int64
# MarginalWorkersRuralPersons     int64
# MarginalWorkersRuralMales       int64
# MarginalWorkersRuralFemales     int64
# MarginalWorkersUrbanPersons     int64
# MarginalWorkersUrbanMales       int64
# MarginalWorkersUrbanFemales     int64
# ...

# %%
# drooping unnecessary columns
columns_to_drop = ["StateCode","DistrictCode","Division","Group","Class"]
df = df.drop(columns= columns_to_drop)

# %%
df.columns
# Out:
# Index(['IndiaStates', 'NICName', 'MainWorkersTotalPersons',
#        'MainWorkersTotalMales', 'MainWorkersTotalFemales',
#        'MainWorkersRuralPersons', 'MainWorkersRuralMales',
#        'MainWorkersRuralFemales', 'MainWorkersUrbanPersons',
#        'MainWorkersUrbanMales', 'MainWorkersUrbanFemales',
#        'MarginalWorkersTotalPersons', 'MarginalWorkersTotalMales',
#        'MarginalWorkersTotalFemales', 'MarginalWorkersRuralPersons',
#        'MarginalWorkersRuralMales', 'MarginalWorkersRuralFemales',
#        'MarginalWorkersUrbanPersons', 'MarginalWorkersUrbanMales',
#        'MarginalWorkersUrbanFemales'],
#       dtype='object')

# %%
#Extracting 'State' and 'District' form 'India/State' columns
df[['State','District']] = df['IndiaStates'].str.extract(r'STATE - (\w+)|District - (\w+)',expand=True)
df = df.drop('IndiaStates',axis=1)

# %%
df[['State','District']].isnull().sum()
# Out:
# State       180430
# District     14715
# dtype: int64

# %%
# Fill NaN values in 'State' column with forward fill (ffill)
df['State'] = df['State'].ffill()
df['District'] = df['District'].bfill()

# %%
df[['State','District']].isnull().sum()
# Out:
# State       0
# District    0
# dtype: int64

# %% [markdown]
# #FEATURE ENGINEERING

# %%
# Creating a New 'TotalWorkers' Column by summing 'MainWorkersTotalPersons' and 'MarginalWorkersTotalPersons':
# creating a new 'MaleFemaleRatio' columns by Dividing 'MainWorkersMale' and 'MainWorkersFemale'  
df['TotalWorkers'] = df['MainWorkersTotalPersons'] + df['MarginalWorkersTotalPersons']
df['MaleFemaleRatio'] = df['MainWorkersTotalMales'] / (df['MainWorkersTotalFemales'].replace(0,1))

# %%
df[['TotalWorkers','MaleFemaleRatio']].isnull().sum()
# Out:
# TotalWorkers       0
# MaleFemaleRatio    0
# dtype: int64

# %%
# Creating a New 'TotalPopulation' Column by summing 'MainWorkersTotalPersons' and 'MarginalWorkersTotalPersons':
# creating a new 'WorkRatio' columns by Dividing 'TotalWorkers' and 'TotalPopulation'  
df['TotalPopulation'] = df['MainWorkersTotalPersons'] + df['MarginalWorkersTotalPersons']
df['WorkersRatio'] = df['TotalWorkers'] / df['TotalPopulation']

# %%
df[['TotalPopulation','WorkersRatio']].isnull().sum()
# Out:
# TotalPopulation    0
# WorkersRatio       0
# dtype: int64

# %%
df[['TotalPopulation','WorkersRatio']] = df[['TotalPopulation','WorkersRatio']].astype(int)

# %%
## Download final df
df.to_csv("HRM.csv",index = False)

# %% [markdown]
# FEATCHING GEO MAPS

# %%
#Replace 'File_path' eith the path to csv file
file_path = r'C:\Users\viren\OneDrive\Desktop\IIT-MADARAS(GUVI)\data\lat_long.csv'

df_geo = pd.read_csv(file_path)

# %%
df_geo.nunique()
# Out:
# Unnamed: 0    33
# State.Name    33
# latitude      33
# longitude     32
# dtype: int64

# %%
# Dropping the specified Columns
df_geo = df_geo.drop(['Unnamed: 0','State.Name'],axis=1)

# %%
# Concatenating the DataFrame horizontally (along with columns) based on there index
df_1 = pd.concat([df,df_geo[['latitude','longitude']]],axis=1)

# %%
df_1.head()
# Out:
#                                              NICName  MainWorkersTotalPersons  \
# 0                                              Total                  9017944
# 1  Crop and animal production, hunting and relate...                   450766
# 2                     Growing of non-perennial crops                    12876
# 3  Growing of cereals (except rice), leguminous c...                    12061
# 4                                    Growing of rice                       79
#
#    MainWorkersTotalMales  MainWorkersTotalFemales  MainWorkersRuralPersons  \
# 0                7594737                  1423207                  4469555
# 1                 201572                   249194                   391263
# 2                  10547                     2329                     5644
# 3                   9911                     2150                     5195
# 4                     71                        8                       48
#
# ...

# %%
df_1.columns
# Out:
# Index(['NICName', 'MainWorkersTotalPersons', 'MainWorkersTotalMales',
#        'MainWorkersTotalFemales', 'MainWorkersRuralPersons',
#        'MainWorkersRuralMales', 'MainWorkersRuralFemales',
#        'MainWorkersUrbanPersons', 'MainWorkersUrbanMales',
#        'MainWorkersUrbanFemales', 'MarginalWorkersTotalPersons',
#        'MarginalWorkersTotalMales', 'MarginalWorkersTotalFemales',
#        'MarginalWorkersRuralPersons', 'MarginalWorkersRuralMales',
#        'MarginalWorkersRuralFemales', 'MarginalWorkersUrbanPersons',
#        'MarginalWorkersUrbanMales', 'MarginalWorkersUrbanFemales', 'State',
#        'District', 'TotalWorkers', 'MaleFemaleRatio', 'TotalPopulation',
#        'WorkersRatio', 'latitude', 'longitude'],
#       dtype='object')

# %%
df_1[['latitude','longitude']].isnull().sum()
# Out:
# latitude     194386
# longitude    194386
# dtype: int64

# %%
df_1.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12042    False
# 12043    False
# 12044     True
# 12045    False
# 12046     True
# Length: 195145, dtype: bool

# %%
df_1.columns
# Out:
# Index(['NICName', 'MainWorkersTotalPersons', 'MainWorkersTotalMales',
#        'MainWorkersTotalFemales', 'MainWorkersRuralPersons',
#        'MainWorkersRuralMales', 'MainWorkersRuralFemales',
#        'MainWorkersUrbanPersons', 'MainWorkersUrbanMales',
#        'MainWorkersUrbanFemales', 'MarginalWorkersTotalPersons',
#        'MarginalWorkersTotalMales', 'MarginalWorkersTotalFemales',
#        'MarginalWorkersRuralPersons', 'MarginalWorkersRuralMales',
#        'MarginalWorkersRuralFemales', 'MarginalWorkersUrbanPersons',
#        'MarginalWorkersUrbanMales', 'MarginalWorkersUrbanFemales', 'State',
#        'District', 'TotalWorkers', 'MaleFemaleRatio', 'TotalPopulation',
#        'WorkersRatio', 'latitude', 'longitude'],
#       dtype='object')

# %%
# Calculating the mean of the 'latitude' and 'longitude' columns
mean_latitude = df_1['latitude'].mean()
mean_longitude = df_1['longitude'].mean()

#Filling the missing values with their respective mean values
df_1.loc[:, 'latitude'] = df_1['latitude'].fillna(mean_latitude)
df_1.loc[:, 'longitude'] = df_1['longitude'].fillna(mean_longitude)

# %%
df_1[['latitude','longitude']].isnull().sum()
# Out:
# latitude     0
# longitude    0
# dtype: int64

# %% [markdown]
# FINDING OUTLIERS

# %%
# Select only the numerical columns for outlier detection
numerical_columns = ['MainWorkersTotalPersons', 'MainWorkersTotalMales','MainWorkersTotalFemales',
                      'MainWorkersRuralPersons','MainWorkersRuralMales', 'MainWorkersRuralFemales',
                      'MainWorkersUrbanPersons', 'MainWorkersUrbanMales','MainWorkersUrbanFemales',
                      'MarginalWorkersTotalPersons','MarginalWorkersTotalMales', 'MarginalWorkersTotalFemales',
                      'MarginalWorkersRuralPersons', 'MarginalWorkersRuralMales','MarginalWorkersRuralFemales',
                      'MarginalWorkersUrbanPersons','MarginalWorkersUrbanMales', 'MarginalWorkersUrbanFemales',
                      'TotalWorkers', 'MaleFemaleRatio', 'TotalPopulation','WorkersRatio']

#Calculating outliers using Z-Score
z_scores = df_1[numerical_columns].apply(lambda x: (x - x.mean()) / x.std())

#Set a threshold for Z-score (e.g,3) to identify outliers
threshold = 3
outliers = (z_scores > threshold) | (z_scores < -threshold)

#plotting Boxplot to visualize the Distribution and outliers
plt.figure(figsize=(12,8))
df_1[numerical_columns].boxplot()
plt.title("Box Plot of Numerical columns")
plt.xticks(rotation=90)
plt.show()

# Plotting Box plot separatly for each numerical columns to focus on individual distributions
for column in numerical_columns:
    plt.figure(figsize=(6,4))
    df_1[[column]].boxplot()
    plt.title(f"Box Plot of {column}")
    plt.show()

# %%
# REmoving outliers

# Select only the numerical_columns for outlier detection
numerical_columns = ['MainWorkersTotalPersons', 'MainWorkersTotalMales','MainWorkersTotalFemales',
                      'MainWorkersRuralPersons','MainWorkersRuralMales', 'MainWorkersRuralFemales',
                      'MainWorkersUrbanPersons', 'MainWorkersUrbanMales','MainWorkersUrbanFemales',
                      'MarginalWorkersTotalPersons','MarginalWorkersTotalMales', 'MarginalWorkersTotalFemales',
                      'MarginalWorkersRuralPersons', 'MarginalWorkersRuralMales','MarginalWorkersRuralFemales',
                      'MarginalWorkersUrbanPersons','MarginalWorkersUrbanMales', 'MarginalWorkersUrbanFemales',
                      'TotalWorkers', 'MaleFemaleRatio', 'TotalPopulation','WorkersRatio']

#Calculate Z-scores for each numerical column
z_scores = df_1[numerical_columns].apply(lambda x: (x - x.mean()) /  x.std())

#set a threshold for Z-score (e.g, 3) to identify outliers:
threshold = 3
outliers = (z_scores > threshold) | (z_scores < -threshold)

#removing rows with outliers in any numerical column
df_1_no_outliers = df_1[~outliers.any(axis=1)]

#Visualize the distribution of cleaned data with Box plots
plt.figure(figsize=(12,8))
df_1_no_outliers = df_1[~outliers.any(axis=1)]
df_1_no_outliers[numerical_columns].boxplot() 
plt.title("Box Plot of Numerical Columns (After removing outliers)")
plt.xticks(rotation = 90)
plt.show()

# %%
df_1.shape
# Out:
# (195145, 27)

# %%
df_1['District']
# Out:
# 0        Ganganagar
# 1        Ganganagar
# 2        Ganganagar
# 3        Ganganagar
# 4        Ganganagar
#             ...
# 12042    Malkangiri
# 12043    Malkangiri
# 12044    Malkangiri
# 12045    Malkangiri
# 12046    Malkangiri
# Name: District, Length: 195145, dtype: object

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 195145 entries, 0 to 12046
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   NICName                      195145 non-null  object
#  1   MainWorkersTotalPersons      195145 non-null  int64
#  2   MainWorkersTotalMales        195145 non-null  int64
#  3   MainWorkersTotalFemales      195145 non-null  int64
#  4   MainWorkersRuralPersons      195145 non-null  int64
#  5   MainWorkersRuralMales        195145 non-null  int64
#  6   MainWorkersRuralFemales      195145 non-null  int64
#  7   MainWorkersUrbanPersons      195145 non-null  int64
#  8   MainWorkersUrbanMales        195145 non-null  int64
#  9   MainWorkersUrbanFemales      195145 non-null  int64
#  10  MarginalWorkersTotalPersons  195145 non-null  int64
#  11  MarginalWorkersTotalMales    195145 non-null  int64
# ...

# %%
df_1.nunique()
# Out:
# NICName                          587
# MainWorkersTotalPersons         8679
# MainWorkersTotalMales           7811
# MainWorkersTotalFemales         3970
# MainWorkersRuralPersons         5767
# MainWorkersRuralMales           5218
# MainWorkersRuralFemales         2694
# MainWorkersUrbanPersons         6561
# MainWorkersUrbanMales           5934
# MainWorkersUrbanFemales         2929
# MarginalWorkersTotalPersons     4208
# MarginalWorkersTotalMales       3181
# MarginalWorkersTotalFemales     2850
# MarginalWorkersRuralPersons     3406
# MarginalWorkersRuralMales       2535
# MarginalWorkersRuralFemales     2379
# MarginalWorkersUrbanPersons     2421
# MarginalWorkersUrbanMales       1951
# MarginalWorkersUrbanFemales     1557
# State                             23
# District                         440
# TotalWorkers                    9451
# MaleFemaleRatio                29974
# TotalPopulation                 9451
# WorkersRatio                       1
# ...

# %%
df_1.to_csv("new_df.csv",index= False)

# %% [markdown]
# Natural Language Processing(NLP)

# %%
df_2 = pd.read_csv("new_df.csv")
df_2.head()
# Out:
#                                              NICName  MainWorkersTotalPersons  \
# 0                                              Total                  9017944
# 1  Crop and animal production, hunting and relate...                   450766
# 2                     Growing of non-perennial crops                    12876
# 3  Growing of cereals (except rice), leguminous c...                    12061
# 4                                    Growing of rice                       79
#
#    MainWorkersTotalMales  MainWorkersTotalFemales  MainWorkersRuralPersons  \
# 0                7594737                  1423207                  4469555
# 1                 201572                   249194                   391263
# 2                  10547                     2329                     5644
# 3                   9911                     2150                     5195
# 4                     71                        8                       48
#
# ...

# %%
df_2.columns.tolist()
# Out:
# ['NICName',
#  'MainWorkersTotalPersons',
#  'MainWorkersTotalMales',
#  'MainWorkersTotalFemales',
#  'MainWorkersRuralPersons',
#  'MainWorkersRuralMales',
#  'MainWorkersRuralFemales',
#  'MainWorkersUrbanPersons',
#  'MainWorkersUrbanMales',
#  'MainWorkersUrbanFemales',
#  'MarginalWorkersTotalPersons',
#  'MarginalWorkersTotalMales',
#  'MarginalWorkersTotalFemales',
#  'MarginalWorkersRuralPersons',
#  'MarginalWorkersRuralMales',
#  'MarginalWorkersRuralFemales',
#  'MarginalWorkersUrbanPersons',
#  'MarginalWorkersUrbanMales',
#  'MarginalWorkersUrbanFemales',
#  'State',
#  'District',
#  'TotalWorkers',
#  'MaleFemaleRatio',
#  'TotalPopulation',
#  'WorkersRatio',
#  'latitude',
#  'longitude']

# %%
df_2['NICName'].unique()
# Out:
# array(['Total',
#        'Crop and animal production, hunting and related service activities',
#        'Growing of non-perennial crops',
#        'Growing of cereals (except rice), leguminous crops and oil seeds',
#        'Growing of rice',
#        'Growing of vegetables and melons, roots and tubers',
#        'Growing of sugar cane', 'Growing of fibre crops',
#        'Growing of other non-perennial crop',
#        'Growing of perennial crops',
#        'Growing of tropical and subtropical fruits',
#        'Growing of citrus fruits',
#        'Growing of pome fruits and stone fruits',
#        'Growing of other tree and bush fruits and nuts',
#        'Growing of oleaginous fruits', 'Growing of beverage crops',
#        'Growing of spices, aromatic, drug and pharmaceutical crops',
#        'Growing of other perennial crops', 'Plant propagation',
#        'Animal production', 'Raising of cattle and buffaloes',
#        'Raising of horses and other equines',
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
# import numpy as np
from sklearn.decomposition import PCA
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import silhouette_score
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string
import nltk
# nltk.download('punkt')
import nltk
# nltk.download('stopwords')
from nltk.probability import FreqDist
from wordcloud import WordCloud
# import matplotlib.pyplot as plt
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
df_2.dtypes
# Out:
# NICName                         object
# MainWorkersTotalPersons          int64
# MainWorkersTotalMales            int64
# MainWorkersTotalFemales          int64
# MainWorkersRuralPersons          int64
# MainWorkersRuralMales            int64
# MainWorkersRuralFemales          int64
# MainWorkersUrbanPersons          int64
# MainWorkersUrbanMales            int64
# MainWorkersUrbanFemales          int64
# MarginalWorkersTotalPersons      int64
# MarginalWorkersTotalMales        int64
# MarginalWorkersTotalFemales      int64
# MarginalWorkersRuralPersons      int64
# MarginalWorkersRuralMales        int64
# MarginalWorkersRuralFemales      int64
# MarginalWorkersUrbanPersons      int64
# MarginalWorkersUrbanMales        int64
# MarginalWorkersUrbanFemales      int64
# State                           object
# District                        object
# TotalWorkers                     int64
# MaleFemaleRatio                float64
# TotalPopulation                  int64
# ...

# %%
df_2['NICName'] = df_2['NICName'].astype(str)

def clean_and_tokenize(text):
    #convert to lowercase
    text = text.lower()

    #Remove Punctuation
    text = text.translate(str.maketrans("", "", string.punctuation))

    #Tokenization
    tokens = word_tokenize(text)

    #Remove Stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]

    return tokens

# Apply the function to your textual data
df_2['NICName'] = df_2['NICName'].apply(clean_and_tokenize)

# %%
# !pip install wordcloud
# !pip install gensim
# !pip install folium

# %%
from gensim.models import Word2Vec

#Assuming 'cleaned_tokens' is the column containing tokenized text
sentences = df_2['NICName'].tolist()

#train Word2Vec model
model = Word2Vec(df_2['NICName'], vector_size = 100, window=5, min_count=1,workers=4)

#Save the Word2Vec model
model.save("word2Vec_model")

#you can use the trained Word2Vec model to get word vectors'
word_to_check = 'uranium'
word_vector = model.wv[word_to_check]

# %%
word_vector
# Out:
# array([ 0.00810041,  0.00370044, -0.07396153, -0.03692569, -0.04040163,
#        -0.06018752, -0.03663865,  0.08879524, -0.10617347,  0.06257255,
#         0.02152536, -0.03200554,  0.01210086,  0.09007427, -0.04940693,
#        -0.07738014,  0.05567494, -0.07986387, -0.03154263, -0.09317864,
#         0.0990432 , -0.02807056,  0.01086285,  0.00792816, -0.00125101,
#         0.0367179 ,  0.00316729, -0.01572728, -0.00696744,  0.09797162,
#         0.05613507,  0.0310898 , -0.0348038 , -0.11975242, -0.00717682,
#         0.04627797, -0.02462056, -0.01269267,  0.02638206, -0.11903159,
#        -0.02571477, -0.07756133,  0.00342409,  0.00449759, -0.00354612,
#         0.01849763, -0.04433786,  0.06346332,  0.0297195 ,  0.01229834,
#         0.01631842, -0.0425219 ,  0.03683847, -0.03388336,  0.00615415,
#        -0.03716974,  0.01999413,  0.07444248,  0.01306941,  0.06975093,
#         0.09332284, -0.0633826 ,  0.00915023, -0.10647799, -0.03779159,
# ...

# %%
print(model)
# Out:
# Word2Vec<vocab=707, vector_size=100, alpha=0.025>

# %%
# calculate word frequencies
all_tokens = [token for token_list in df_2['NICName'] for token in token in token_list]
freq_dist = [FreqDist(all_tokens)]

#Visualize word frequencies using a word cloud
WordCloud = WordCloud(width=800,height=400,background_color='white').generate_from_frequencies(freq_dist)
plt.figure(figsize=(10,50))
plt.imshow(WordCloud,interpolation='bilinear')
plt.axes('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[66], line 2
#       1 # calculate word frequencies
# ----> 2 all_tokens = [token for token_list in df_2['NICName'] for token in token in token_list]
#       3 freq_dist = [FreqDist(all_tokens)]
#       5 #Visualize word frequencies using a word cloud
#
# Cell In[66], line 2, in <listcomp>(.0)
#       1 # calculate word frequencies
# ----> 2 all_tokens = [token for token_list in df_2['NICName'] for token in token in token_list]
#       3 freq_dist = [FreqDist(all_tokens)]
#       5 #Visualize word frequencies using a word cloud
#
# UnboundLocalError: cannot access local variable 'token' where it is not associated with a value
