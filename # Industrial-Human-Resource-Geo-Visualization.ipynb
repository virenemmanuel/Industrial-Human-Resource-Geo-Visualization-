# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18_0800_NIC_FINAL_STATE_RAJASTHAN-2011.csv",encoding='latin1')
df2 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18_1200_NIC_FINAL_STATE_ARUNACHAL_PRADESH-2011.csv",encoding='latin1')
df3 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18_1400_NIC_FINAL_STATE_MANIPUR-2011.csv",encoding='latin1')
df4 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18_1500_NIC_FINAL_STATE_MIZORAM-2011.csv",encoding='latin1')
df5 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18_1900_NIC_FINAL_STATE_WEST_BENGAL-2011.csv",encoding='latin1')
df6 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18sc_0700_NIC_FINAL_STATE_NCT_OF_DELHI-2011.csv",encoding='latin1')
df7 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18sc_1600_NIC_FINAL_STATE_TRIPURA-2011.csv",encoding='latin1')
df8 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18sc_2000_NIC_FINAL_STATE_JHARKHAND-2011.csv",encoding='latin1')
df9 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18sc_2400_NIC_FINAL_STATE_GUJARAT-2011.csv",encoding='latin1')
df10 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18sc_2700_NIC_FINAL_STATE_MAHARASHTRA-2011.csv",encoding='latin1')
df11= pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18sc_2900_NIC_FINAL_STATE_KARNATAKA-2011.csv",encoding='latin1')
df12= pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18sc_3000_NIC_FINAL_STATE_GOA-2011.csv",encoding='latin1')
df13= pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18sc_3200_NIC_FINAL_STATE_KERALA-2011.csv",encoding='latin1')
df14 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18sc_3300_NIC_FINAL_STATE_TAMIL_NADU-2011.csv",encoding='latin1')
df15= pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18sc_3400_NIC_FINAL_STATE_PUDUCHERRY-2011.csv",encoding='latin1')
df16= pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18st_0200_NIC_FINAL_STATE_HIMACHAL_PRADESH-2011.csv",encoding='latin1')
df17 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18st_0500_NIC_FINAL_STATE_UTTARAKHAND-2011.csv",encoding='latin1')
df18 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18st_0900_NIC_FINAL_STATE_UTTAR_PRADESH-2011.csv",encoding='latin1')
df19 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18st_1000_NIC_FINAL_STATE_BIHAR-2011.csv",encoding='latin1')
df20 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18st_1100_NIC_FINAL_STATE_SIKKIM-2011.csv",encoding='latin1')
df21 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18st_1300_NIC_FINAL_STATE_NAGALAND-2011.csv",encoding='latin1')
df22 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18st_1800_NIC_FINAL_STATE_ASSAM-2011.csv",encoding='latin1')
df23 = pd.read_csv("C:/Users/viren/OneDrive/Desktop/IIT-MADARAS(GUVI)/data/DDW_B18st_2100_NIC_FINAL_STATE_ODISHA-2011.csv",encoding='latin1')

# %%
df = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23])
df.head()
# Out:
#   State Code District Code       India/States Division Group  Class  \
# 0        `08          `000  STATE - RAJASTHAN      `00  `000  `0000
# 1        `08          `000  STATE - RAJASTHAN      `01  `000  `0000
# 2        `08          `000  STATE - RAJASTHAN      `01  `011  `0000
# 3        `08          `000  STATE - RAJASTHAN      `01  `011  `0111
# 4        `08          `000  STATE - RAJASTHAN      `01  `011  `0112
#
#                                             NIC Name  \
# 0                                              Total
# 1  Crop and animal production, hunting and relate...
# 2                     Growing of non-perennial crops
# 3  Growing of cereals (except rice), leguminous c...
# 4                                    Growing of rice
#
#    Main Workers - Total -  Persons  Main Workers - Total - Males  \
# 0                          9017944                       7594737
# 1                           450766                        201572
# ...

# %%
df.shape
# Out:
# (195145, 25)

# %%
df.to_csv("All_Combine.csv",index=False)

# %%
#  removing unnecessary characters (such as commas, semicolons, and backticks) and converting the cleaned values to integers.
df['State Code'] = df['State Code'].astype(str).str.replace('`','').astype(int)
df['District Code'] = df['District Code'].astype(str).str.replace('`','').astype(int)
df['Division'] = df['Division'].astype(str).str.replace('`','').astype(int)
df['Group'] = df['Group'].astype(str).str.replace('`','').astype(int)
df['Class'] = df['Class'].astype(str).str.replace('`','').astype(int)

# %%
df.columns
# Out:
# Index(['State Code', 'District Code', 'India/States', 'Division', 'Group',
#        'Class', 'NIC Name', 'Main Workers - Total -  Persons',
#        'Main Workers - Total - Males', 'Main Workers - Total - Females',
#        'Main Workers - Rural -  Persons', 'Main Workers - Rural - Males',
#        'Main Workers - Rural - Females', 'Main Workers - Urban -  Persons',
#        'Main Workers - Urban - Males', 'Main Workers - Urban - Females',
#        'Marginal Workers - Total -  Persons',
#        'Marginal Workers - Total - Males',
#        'Marginal Workers - Total - Females',
#        'Marginal Workers - Rural -  Persons',
#        'Marginal Workers - Rural - Males',
#        'Marginal Workers - Rural - Females',
#        'Marginal Workers - Urban -  Persons',
#        'Marginal Workers - Urban - Males',
#        'Marginal Workers - Urban - Females'],
#       dtype='object')

# %%
# removing special characters from the column names.

def remove_special_character(column_name):
    return ''.join(e for e in column_name if e.isalnum() or e in ('_','.'))

df.columns = [remove_special_character(col) for col in df.columns]

# %%
df.columns
# Out:
# Index(['StateCode', 'DistrictCode', 'IndiaStates', 'Division', 'Group',
#        'Class', 'NICName', 'MainWorkersTotalPersons', 'MainWorkersTotalMales',
#        'MainWorkersTotalFemales', 'MainWorkersRuralPersons',
#        'MainWorkersRuralMales', 'MainWorkersRuralFemales',
#        'MainWorkersUrbanPersons', 'MainWorkersUrbanMales',
#        'MainWorkersUrbanFemales', 'MarginalWorkersTotalPersons',
#        'MarginalWorkersTotalMales', 'MarginalWorkersTotalFemales',
#        'MarginalWorkersRuralPersons', 'MarginalWorkersRuralMales',
#        'MarginalWorkersRuralFemales', 'MarginalWorkersUrbanPersons',
#        'MarginalWorkersUrbanMales', 'MarginalWorkersUrbanFemales'],
#       dtype='object')

# %%
df.head()
# Out:
#    StateCode  DistrictCode        IndiaStates  Division  Group  Class  \
# 0          8             0  STATE - RAJASTHAN         0      0      0
# 1          8             0  STATE - RAJASTHAN         1      0      0
# 2          8             0  STATE - RAJASTHAN         1     11      0
# 3          8             0  STATE - RAJASTHAN         1     11    111
# 4          8             0  STATE - RAJASTHAN         1     11    112
#
#                                              NICName  MainWorkersTotalPersons  \
# 0                                              Total                  9017944
# 1  Crop and animal production, hunting and relate...                   450766
# 2                     Growing of non-perennial crops                    12876
# 3  Growing of cereals (except rice), leguminous c...                    12061
# 4                                    Growing of rice                       79
#
#    MainWorkersTotalMales  MainWorkersTotalFemales  ...  \
# ...

# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
# Select Non-Numeric Columns: 
non_numeric_columns = df.select_dtypes(exclude=[float, int]).columns

# Drop Non-Numeric Columns:
numeric_df = df.drop(columns=non_numeric_columns)

# Calculate Correlation: 
correlation_matrix = numeric_df.corr()
correlation_matrix
# Out:
#                              StateCode  DistrictCode  Division     Group  \
# StateCode                     1.000000      0.851207 -0.010642 -0.001695
# DistrictCode                  0.851207      1.000000 -0.005517 -0.005349
# Division                     -0.010642     -0.005517  1.000000  0.744991
# Group                        -0.001695     -0.005349  0.744991  1.000000
# Class                         0.003277     -0.004001  0.438274  0.593097
# MainWorkersTotalPersons      -0.003645     -0.028298 -0.010332 -0.014413
# MainWorkersTotalMales        -0.004775     -0.027999 -0.010797 -0.014439
# MainWorkersTotalFemales       0.001599     -0.027503 -0.007516 -0.013226
# MainWorkersRuralPersons      -0.004710     -0.028544 -0.013753 -0.016427
# MainWorkersRuralMales        -0.005690     -0.028156 -0.013073 -0.015752
# MainWorkersRuralFemales      -0.000498     -0.027300 -0.015046 -0.017440
# MainWorkersUrbanPersons      -0.002714     -0.027413 -0.007376 -0.012471
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def correlation_matrix():
    numberic_df = df.select_dtypes(include= ['float64','int64'])

    plt.figure(figsize=(12,10))
    sns.heatmap(numberic_df.corr(),annot=True,cmap= 'coolwarm', fmt='.2f')
    plt.title('Correlation_Matrix')
    plt.show()

correlation_matrix()

# %%
df.shape
# Out:
# (195145, 25)

# %%
df.head()
# Out:
#    StateCode  DistrictCode        IndiaStates  Division  Group  Class  \
# 0          8             0  STATE - RAJASTHAN         0      0      0
# 1          8             0  STATE - RAJASTHAN         1      0      0
# 2          8             0  STATE - RAJASTHAN         1     11      0
# 3          8             0  STATE - RAJASTHAN         1     11    111
# 4          8             0  STATE - RAJASTHAN         1     11    112
#
#                                              NICName  MainWorkersTotalPersons  \
# 0                                              Total                  9017944
# 1  Crop and animal production, hunting and relate...                   450766
# 2                     Growing of non-perennial crops                    12876
# 3  Growing of cereals (except rice), leguminous c...                    12061
# 4                                    Growing of rice                       79
#
#    MainWorkersTotalMales  MainWorkersTotalFemales  ...  \
# ...

# %%
#n
